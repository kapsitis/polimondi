# %%
from polyforms.polyiamond import Polyiamond
from polyforms.draw_scene import *

mylist = [
'ABCDEFDEFAB',
'ABCDEFDFEAC',
'ABCDFEDEFAC',
'ABCDFEDEFBF',
'ABDCEAEDFEF',
'ABDCEFDEAFB',
'ABDECDFAEAE',
'ABDECDFAEFB',
'ABDECDFAFDF',
'ABDFDBDEFDF',
'ABDFDBDFEDE',
'ACBDEFDFEAB',
'ACBDFEDEFAB',
'ACBDFEDFEAC',
'ACDBDFEFAFE',
'ACDCEAFEFAB',
'ACDCEFAEAFB',
'ACDEACAEFDF',
'ACDEACAFEDE',
'ACDEFBCAEFE',
'ACDFDEABFBC'
]
offsets = [(0,0), (0,0), (0,0), (0,0)]

polygons = [Polyiamond(s) for s in mylist[0:4]]
scene = DrawScene(Align.BASELINE)

for idx,poly in enumerate(polygons):
    scene.add_polyiamond(f'p{idx}', poly, offsets[idx])
    
scene.pack()
scene.show_grid()
scene.set_size_in(16,6)
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.

# %%
from polyforms.polyiamond import Polyiamond
from polyforms.draw_scene import *

mylist = [
'ABCDEFDEFAB',
'ABCDEFDFEAC',
'ABCDFEDEFAC',
'ABCDFEDEFBF',
'ABDCEAEDFEF',
'ABDCEFDEAFB',
'ABDECDFAEAE',
'ABDECDFAEFB',
'ABDECDFAFDF',
'ABDFDBDEFDF',
'ABDFDBDFEDE',
'ACBDEFDFEAB',
'ACBDFEDEFAB',
'ACBDFEDFEAC',
'ACDBDFEFAFE',
'ACDCEAFEFAB',
'ACDCEFAEAFB',
'ACDEACAEFDF',
'ACDEACAFEDE',
'ACDEFBCAEFE',
'ACDFDEABFBC'
]
offsets = [(0,0), (0,0), (0,0), (0,0)]

polygons = [Polyiamond(s) for s in mylist[4:8]]
scene = DrawScene(Align.BASELINE)

for idx,poly in enumerate(polygons):
    scene.add_polyiamond(f'p{idx}', poly, offsets[idx])
    
scene.pack()
scene.show_grid()
scene.set_size_in(16,6)
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
