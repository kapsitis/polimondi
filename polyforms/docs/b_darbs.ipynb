# %%
from polyforms.grammar import *
from polyforms.polyiamond import Polyiamond
from polyforms.draw_scene import *
from polyforms.n_gon import *

# 'ABCBC.DEAEFE.DEFEF.ABDBC.',[['BC.','FE.','EF.','BC.']]

axiom = '[P]fdb'
rule0 = {'P':'cbcb[P]fefe'}
rule1 = {'P':'cae'}
g = Grammar(axiom, [rule0, rule1])
pp = [g.derive([0]*i + [1]) for i in range(3)]

print([p.lower() for p in pp])

print([len(p) for p in pp])
poly = [Polyiamond(p) for p in pp]

# offsets = [(0,0), (0,0), (0,0)]

# scene = DrawScene(Align.BASELINE)
# for idx,poly in enumerate(poly):
#     scene.add_polyiamond(f'p{idx}', poly, (offsets[idx]))

# scene.pack()
# scene.set_size_in(6,7)

# %%
from polyforms.grammar import *
from polyforms.polyiamond import Polyiamond
from polyforms.draw_scene import *
from polyforms.n_gon import *

# Grammar G_2 from bakalaura darbs
axiom = 'a[P1]cacd[P2]e[P2]fdfdfa[P1]b'
rule0 = {'P1':'ca[P1]', 'P2':'fd[P2]'}
g = Grammar(axiom, [rule0])
pp = [g.derive([0]*i) for i in range(3)]

print([p.lower() for p in pp])

print([len(p) for p in pp])
poly = [Polyiamond(p) for p in pp]

offsets = [(0,0), (0,0), (0,0)]

scene = DrawScene(Align.BASELINE)
for idx,poly in enumerate(poly):
    scene.add_polyiamond(f'p{idx}', poly, (offsets[idx]))

scene.pack()
scene.set_size_in(6,7)

# %%
from polyforms.grammar import *
from polyforms.polyiamond import Polyiamond
from polyforms.draw_scene import *
from polyforms.n_gon import *

# \mathbf{S} &\to& \mathbf{P}_1\,\mathtt{ace}\,\mathbf{P}_2\,\mathtt{dfb}\,\mathbf{P}_1 \\
# (\mathbf{P}_1,\; \mathbf{P}_2) &\to& (\mathbf{P}_1\,\mathtt{ab},\; \mathbf{P}_2\,\mathtt{dede}) \\
# (\mathbf{P}_1,\; \mathbf{P}_2) &\to& (\varepsilon,\; \varepsilon)\\

axiom = '[P1]ace[P2]dfb[P1]'
rule0 = {'P1':'[P1]ab', 'P2': '[P2]dede'}
g = Grammar(axiom, [rule0])
pp = [g.derive([0]*i) for i in range(3)]

print([p.lower() for p in pp])

print([len(p) for p in pp])
poly = [Polyiamond(p) for p in pp]

offsets = [(0,0), (-20,0), (-75,0)]

scene = DrawScene(Align.BASELINE)
for idx,poly in enumerate(poly):
    scene.add_polyiamond(f'p{idx}', poly, (offsets[idx]))

scene.pack()
scene.show_grid()
scene.set_size_in(12,5)

# %%
from polyforms.grammar import *
from polyforms.polyiamond import Polyiamond
from polyforms.draw_scene import *
from polyforms.n_gon import *

# (AB)^kABAF(ED)^kEDED(EF)^kED(CB)^kCBCB(CD)^kCB(AF)^kAB

axiom = '[P1]abaf[P2]eded[P3]ed[P4]cbcb[P5]cb[P6]ab'
rule0 = {'P1':'[P1]ab', 'P2': '[P2]ed', 'P3': '[P3]ef', 'P4': '[P4]cb', 'P5': '[P5]cd', 'P6': '[P6]af'}
g = Grammar(axiom, [rule0])
pp = [g.derive([0]*i) for i in range(3)]

print([p.lower() for p in pp])

print([len(p) for p in pp])
poly = [Polyiamond(p) for p in pp]

offsets = [(0,0), (-60,-35), (-200,-90)]

scene = DrawScene(Align.BASELINE)
for idx,poly in enumerate(poly):
    scene.add_polyiamond(f'p{idx}', poly, (offsets[idx]))

scene.pack()
# scene.show_grid()
scene.set_size_in(12,5)

# %%
from polyforms.grammar import *
from polyforms.polyiamond import Polyiamond
from polyforms.draw_scene import *
from polyforms.n_gon import *

# (AB)^kABC(DE)^kDE(DC)^kDE(FA)^kFA(FE)^kFA(BC)^kB

axiom = '[P1]abc[P2]de[P3]de[P4]fa[P5]fa[P6]b'
rule0 = {'P1':'[P1]ab', 'P2': '[P2]de', 'P3': '[P3]dc', 'P4': '[P4]fa', 'P5': '[P5]fe', 'P6': '[P6]bc'}
g = Grammar(axiom, [rule0])
pp = [g.derive([0]*i) for i in range(3)]

# pp = ['ABCDEDEFAFAB', 'ABABCDEDEDCDEFAFAFEFABCB', 'ABABABCDEDEDEDCDCDEFAFAFAFEFEFABCBCB']

print([p.lower() for p in pp])

print([len(p) for p in pp])
poly = [Polyiamond(p) for p in pp]

offsets = [(0,0), (-50,0), (-130,0)]

scene = DrawScene(Align.BASELINE)
for idx,poly in enumerate(poly):
    scene.add_polyiamond(f'p{idx}', poly, (offsets[idx]))

scene.pack()
# scene.show_grid()
scene.set_size_in(12,5)

# %%
from polyforms.grammar import *
from polyforms.polyiamond import Polyiamond
from polyforms.draw_scene import *
from polyforms.n_gon import *

# (AB)^kABAF(ED)^kED(EF)^kEDED(CB)^kCB(CD)^kCBCBAB(AF)^k

axiom = '[P1]abaf[P2]ed[P3]eded[P4]cb[P5]cbcbab[P6]'
rule0 = {'P1':'[P1]ab', 'P2': '[P2]ed', 'P3': '[P3]ef', 'P4': '[P4]cb', 'P5': '[P5]cd', 'P6': '[P6]af'}
g = Grammar(axiom, [rule0])
pp = [g.derive([0]*i) for i in range(3)]

# pp = ['ABCDEDEFAFAB', 'ABABCDEDEDCDEFAFAFEFABCB', 'ABABABCDEDEDEDCDCDEFAFAFAFEFEFABCBCB']

print([p.lower() for p in pp])

print([len(p) for p in pp])
poly = [Polyiamond(p) for p in pp]

offsets = [(0,0), (-50,0), (-130,0)]

scene = DrawScene(Align.BASELINE)
for idx,poly in enumerate(poly):
    scene.add_polyiamond(f'p{idx}', poly, (offsets[idx]))

scene.pack()
# scene.show_grid()
scene.set_size_in(12,5)
