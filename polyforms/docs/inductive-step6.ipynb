# %%
from polyforms.draw_scene import *
from polyforms.perfect_seq import *
from polyforms.poly_geometry import PolyGeometry
from polyforms.point_tg import *
import numpy as np

TH = np.sqrt(3)/2
storage = PerfectSeq()

myseq = storage.get_sequence('SEQ_4_3_A')
scene = DrawScene(-4, -8, 80, 80, '#999999', 'solid', 0.25)
scene.draw_seq('p0', myseq[0], 'b', [0.0,0.0])
scene.draw_seq('p1', myseq[1], 'b', [25.0,0.0])
scene.draw_seq('p2', myseq[2], 'b', [50.0,0.0])

# %%
from polyforms.draw_scene import *
from polyforms.perfect_seq import *
from polyforms.poly_geometry import PolyGeometry
from polyforms.point_tg import *
import numpy as np

storage = PerfectSeq()

myseq_6_5_B = storage.get_sequence('SEQ_6_5_B')
print(myseq_6_5_B[0])

polygons = []
for i in range(3):
    N = len(myseq_6_5_B[i])
    polygon = PolyGeometry(list(zip(range(N,0,-1), myseq_6_5_B[i])))

scene = DrawScene(-10, -30, 260, 240, '#999999', 'solid', 0.25)
scene.draw_seq('p0', myseq_6_5_B[0], 'k', [0.0,0.0])
scene.draw_seq('p1', myseq_6_5_B[1], 'k', [60.0,0.0])
scene.draw_seq('p2', myseq_6_5_B[2], 'k', [140.0,0.0])

scene.set_size_in(14,10)
# Out:
# ACBACBDFEDFEDFEDFEACBAC

# %%
seq1 = 'ACBABCBDFEDFDFEDFEDEFEACBACAC'
seq2 = 'ABCBACBDFEDFDFEDEFEDFEACBACAC'

scene2 = DrawScene(-10, -30, 260, 240, '#999999', 'solid', 0.25)

scene2.draw_seq('seq1', seq1, 'k', [0.0,0.0])
scene2.draw_seq('seq2', seq2, 'k', [60.0,0.0])

scene2.highlight('seq1', [4, 12, 13, 19, 27, 28], '#2D9BF0')

scene2.set_size_in(14,10)
