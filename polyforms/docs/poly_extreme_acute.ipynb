# %%
from polyforms.polyiamond import Polyiamond
from polyforms.draw_scene import *

mylist = ['ACECEAEAC', 'ACAEAEAECECECECECACACACACAC', 'ACACECACECECEAEAEAEAEAECEAEAC']
print([len(x) for x in mylist])
polygons = [Polyiamond(s) for s in mylist]
scene = DrawScene(Align.BASELINE)

offsets = [(0,-20),(-40,0), (-30,-40)]

for idx,poly in enumerate(polygons):
    scene.add_polyiamond(f'p{idx}', poly, offsets[idx])
    
scene.pack()
# scene.show_grid()
scene.set_size_in(16,8)
# Out:
# [9, 27, 29]

# %%
from polyforms.polyiamond import Polyiamond
from polyforms.draw_scene import *

mylist = ['ACACACECECECEAEAECEAEAEAEAEACACAC', 'ACACAEAEAEAECECECECECECECACACACACAC', 'ACACECECECEAECEAEAEAEAEACACACACACACACAC']
print([len(x) for x in mylist])
polygons = [Polyiamond(s) for s in mylist]
scene = DrawScene(Align.BASELINE)

offsets = [(0,0),(-50,20), (-10,20)]

for idx,poly in enumerate(polygons):
    scene.add_polyiamond(f'p{idx}', poly, offsets[idx])
    
scene.pack()
#scene.show_grid()
scene.set_size_in(16,6)
# Out:
# [33, 35, 39]

# %%
from polyforms.polyiamond import Polyiamond
from polyforms.draw_scene import *

mylist = ['ACAEAEAEAECECECECECACACECACACECACACAEAEAE', 'ACACACECECECECEAEAEAECEAEAEAEACACACAEACACACAC', 'ACACACACECECECECECEAEAEAEAEACAEAEAEAECEAEACAEAE']
print([len(x) for x in mylist])
polygons = [Polyiamond(s) for s in mylist]
scene = DrawScene(Align.BASELINE)

offsets = [(0,0),(20,-40), (40,-70)]

for idx,poly in enumerate(polygons):
    scene.add_polyiamond(f'p{idx}', poly, offsets[idx])
    
scene.pack()
#scene.show_grid()
scene.set_size_in(16,6)
# Out:
# [41, 45, 47]

# %%
from polyforms.polyiamond import Polyiamond
from polyforms.draw_scene import *

mylist = ['ACAEAEAEAEAECECECECECECECACACACACACECACACACACAEAEAC', 'ACACACACACECECECECECEAEAECEAEAEAEAEAEAEAECEAEACAEAEAE']
print([len(x) for x in mylist])
polygons = [Polyiamond(s) for s in mylist]
scene = DrawScene(Align.BASELINE)

offsets = [(0,0),(20,-160)]

for idx,poly in enumerate(polygons):
    scene.add_polyiamond(f'p{idx}', poly, offsets[idx])
    
scene.pack()
#scene.show_grid()
scene.set_size_in(16,6)
# Out:
# [51, 53]

# %%
from polyforms.polyiamond import Polyiamond
from polyforms.draw_scene import *

mylist = ['ACACACACACECECECECECECEAEAEAEAEAEAEAECEAEAEAEAEACACACACAC', 'ACACACACECECECECECECEAEAEAEAEAEAEAEAEAEACACACACACACECECACAC']
print([len(x) for x in mylist])
polygons = [Polyiamond(s) for s in mylist]
scene = DrawScene(Align.BASELINE)

offsets = [(0,0),(20,50)]

for idx,poly in enumerate(polygons):
    scene.add_polyiamond(f'p{idx}', poly, offsets[idx])
    
scene.pack()
#scene.show_grid()
scene.set_size_in(16,6)
# Out:
# [57, 59]

# %%
from polyforms.polyiamond import Polyiamond
from polyforms.draw_scene import *

mylist = ['ACECEAEAC', 'ACAEAEAECECACECECECACECACAC', 'ACECECEAEACAEAEACACECACECACAE']
print([len(x) for x in mylist])
polygons = [Polyiamond(s) for s in mylist]
scene = DrawScene(Align.BASELINE)

offsets = [(0,0),(-40,0), (-10,0)]

for idx,poly in enumerate(polygons):
    scene.add_polyiamond(f'p{idx}', poly, offsets[idx])
    
scene.pack()
#scene.show_grid()
scene.set_size_in(16,6)
# Out:
# [9, 27, 29]

# %%
from polyforms.polyiamond import Polyiamond
from polyforms.draw_scene import *

mylist = ['ACECECEAEAEAEACACECACECACACACAEAC', 'ACACAEAECEAECEAECECACECECECACAEACAE', 'ACECACECEAECECEAEACAEACAEACACAEAEAEACAC']
print([len(x) for x in mylist])
polygons = [Polyiamond(s) for s in mylist]
scene = DrawScene(Align.BASELINE)

offsets = [(0,0),(-40,-20), (0,-20)]

for idx,poly in enumerate(polygons):
    scene.add_polyiamond(f'p{idx}', poly, offsets[idx])
    
scene.pack()
#scene.show_grid()
scene.set_size_in(16,6)
# Out:
# [33, 35, 39]

# %%
from polyforms.polyiamond import Polyiamond
from polyforms.draw_scene import *

mylist = ['ACECECEAEAEAEACACECACECACECACAEACAEAEACAC', 'ACECACACECEAECEAECECEAEACAEACAEACAEAEAEACACAE', 'ACACECACACECEAECEAECEAEACAEAEAECECECEAEAEACAEAE']
print([len(x) for x in mylist])
polygons = [Polyiamond(s) for s in mylist]
scene = DrawScene(Align.BASELINE)

offsets = [(0,0),(0,-80), (0,-80)]

for idx,poly in enumerate(polygons):
    scene.add_polyiamond(f'p{idx}', poly, offsets[idx])
    
scene.pack()
#scene.show_grid()
scene.set_size_in(16,6)
# Out:
# [41, 45, 47]

# %%
from polyforms.polyiamond import Polyiamond
from polyforms.draw_scene import *

mylist = ['ACAEAECEAECECACECECECACAEACACAEAECEAEAEACACECACACAC', 'ACECECACAEACAEACAEAECEAEAEAECECACECECACECECECECACACAE']
print([len(x) for x in mylist])
polygons = [Polyiamond(s) for s in mylist]
scene = DrawScene(Align.BASELINE)

offsets = [(0,0),(10,-20),(0,0)]

for idx,poly in enumerate(polygons):
    scene.add_polyiamond(f'p{idx}', poly, offsets[idx])
    
scene.pack()
#scene.show_grid()
scene.set_size_in(16,7)
# Out:
# [51, 53]

# %%
from polyforms.polyiamond import Polyiamond
from polyforms.draw_scene import *

mylist = ['ACAEAEACACAEAECEAEAECECACECECECACACECECECECECECACAEACACAC', 'ACAEAEACACAEAECEAECEAECECACECECACACECECECEAECECACECACACACAC']
print([len(x) for x in mylist])
polygons = [Polyiamond(s) for s in mylist]
scene = DrawScene(Align.BASELINE)

offsets = [(0,0),(10,0),(0,0)]

for idx,poly in enumerate(polygons):
    scene.add_polyiamond(f'p{idx}', poly, offsets[idx])
    
scene.pack()
#scene.show_grid()
scene.set_size_in(16,7)
# Out:
# [57, 59]
